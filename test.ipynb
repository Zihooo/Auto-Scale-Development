# %%
from auto_scale_development import call_llm_api

response = call_llm_api(
    model_name="gemini-2.5-pro",
    system_prompt="You are a world-class poet. Respond only with short poems.",
    user_prompt="How does a CPU work?",
    temperature=0.7,
    top_p=0.9
)
print(response)
# Out:
# A whispered task,
# A crystal mind.
# The gates of logic,
# Swiftly bind.
#
# A pulse of light,
# A naught and one.
# The work of worlds,
# Is thought, and done.

# %%
from auto_scale_development import item_generation, export_items_to_excel, export_items_to_json, item_reduction, content_validation, get_items

# item_generation
# Define the construct and its dimensions
construct = "Interpersonal Distrust"
definition = "An expectation of harmful, hostile, or other negative outcomes in interactions with another person, which may be based on past experiences, observations, or general beliefs about human nature."

dimensions = {
    "Cognitive": "Rational beliefs or expectations about another party's untrustworthiness, including suspicions about their motives, intentions, or reliability.",
    "Behavioral": "The unwillingness or avoidance of future interactions or risk-taking actions with the distrusted person, including protective behaviors.",
    "Affective": "Negative emotions directed at the distrusted person, such as anxiety, fear, anger, or discomfort."
}

# Optional: Provide examples for each dimension
examples = {
    "Cognitive": [
        "This person would behave in a deceptive and fraudulent way.",
        "I am suspicious of the way this person will act in the future."
    ],
    "Behavioral": [
        "I find it necessary to be cautious with this person.",
        "I will protect myself from being taken advantage of by this person."
    ],
    "Affective": [
        "I feel tense when I am with this person.",
        "I experience anxiety when interacting with this person."
    ]
}

## Sample call to item_generation function
# Generate 5 items per dimension (15 total items)
items = item_generation(
    construct=construct,
    definition=definition,
    dimensions=dimensions,
    examples=examples,
    num_items=40,
    model_name="chatgpt-4o-latest",  # Using a faster model for testing
    temperature=0.7,
    top_p=0.8
)

print("Generated Items:")
items
# Out:
# Generated Items:
# {'construct': 'Interpersonal Distrust',
#  'definition': 'An expectation of harmful, hostile, or other negative outcomes in interactions with another person, which may be based on past experiences, observations, or general beliefs about human nature.',
#  'dimensions': {'Cognitive': "Rational beliefs or expectations about another party's untrustworthiness, including suspicions about their motives, intentions, or reliability.",
#   'Behavioral': 'The unwillingness or avoidance of future interactions or risk-taking actions with the distrusted person, including protective behaviors.',
#   'Affective': 'Negative emotions directed at the distrusted person, such as anxiety, fear, anger, or discomfort.'},
#  'items': [{'item_number': 1,
#    'statement': 'I question whether this person has honest intentions.',
#    'dimension': 'Cognitive'},
#   {'item_number': 2,
#    'statement': 'I believe this person hides their true motives.',
#    'dimension': 'Cognitive'},
#   {'item_number': 3,
#    'statement': 'I think this person would take advantage of me if given the chance.',
#    'dimension': 'Cognitive'},
#   {'item_number': 4,
#    'statement': 'I doubt this person would act in my best interest.',
#    'dimension': 'Cognitive'},
#   {'item_number': 5,
#    'statement': 'I suspect this person might mislead me.',
#    'dimension': 'Cognitive'},
#   {'item_number': 6,
#    'statement': 'I believe this person would betray me if it benefited them.',
#    'dimension': 'Cognitive'},
#   {'item_number': 7,
#    'statement': 'I think this person is not dependable.',
#    'dimension': 'Cognitive'},
#   {'item_number': 8,
#    'statement': 'I expect this person to act selfishly.',
#    'dimension': 'Cognitive'},
#   {'item_number': 9,
#    'statement': 'I assume this person will put their needs ahead of mine.',
#    'dimension': 'Cognitive'},
#   {'item_number': 10,
#    'statement': 'I believe this person would deceive me if it helped them.',
#    'dimension': 'Cognitive'},
#   {'item_number': 11,
#    'statement': 'I think this person is not being fully honest with me.',
#    'dimension': 'Cognitive'},
#   {'item_number': 12,
#    'statement': 'I question this person’s ability to keep their promises.',
#    'dimension': 'Cognitive'},
#   {'item_number': 13,
#    'statement': 'I believe this person would manipulate a situation to their advantage.',
#    'dimension': 'Cognitive'},
#   {'item_number': 14,
#    'statement': 'I think this person lacks integrity.',
#    'dimension': 'Cognitive'},
#   {'item_number': 15,
#    'statement': 'I doubt this person would be loyal in a difficult situation.',
#    'dimension': 'Cognitive'},
#   {'item_number': 16,
#    'statement': 'I suspect this person could be two-faced.',
#    'dimension': 'Cognitive'},
#   {'item_number': 17,
#    'statement': 'I believe this person is not trustworthy in private matters.',
#    'dimension': 'Cognitive'},
#   {'item_number': 18,
#    'statement': 'I think this person may lie to protect themselves.',
#    'dimension': 'Cognitive'},
#   {'item_number': 19,
#    'statement': 'I expect this person to act unethically if they could get away with it.',
#    'dimension': 'Cognitive'},
#   {'item_number': 20,
#    'statement': 'I believe this person would break a rule for personal gain.',
#    'dimension': 'Cognitive'},
#   {'item_number': 21,
#    'statement': 'I assume this person would share confidential information without permission.',
#    'dimension': 'Cognitive'},
#   {'item_number': 22,
#    'statement': 'I question this person’s sincerity.',
#    'dimension': 'Cognitive'},
#   {'item_number': 23,
#    'statement': 'I believe this person would exploit my weaknesses.',
#    'dimension': 'Cognitive'},
#   {'item_number': 24,
#    'statement': 'I think this person is not truthful in their communication.',
#    'dimension': 'Cognitive'},
#   {'item_number': 25,
#    'statement': 'I expect this person to be unreliable in important situations.',
#    'dimension': 'Cognitive'},
#   {'item_number': 26,
#    'statement': 'I believe this person would act selfishly in a crisis.',
#    'dimension': 'Cognitive'},
#   {'item_number': 27,
#    'statement': 'I doubt this person would defend me if I were treated unfairly.',
#    'dimension': 'Cognitive'},
#   {'item_number': 28,
#    'statement': 'I assume this person has hidden agendas.',
#    'dimension': 'Cognitive'},
#   {'item_number': 29,
#    'statement': 'I think this person is more concerned about themselves than others.',
#    'dimension': 'Cognitive'},
#   {'item_number': 30,
#    'statement': 'I believe this person would withhold important information.',
#    'dimension': 'Cognitive'},
#   {'item_number': 31,
#    'statement': 'I question this person’s moral values.',
#    'dimension': 'Cognitive'},
#   {'item_number': 32,
#    'statement': 'I expect this person to prioritize their interests over fairness.',
#    'dimension': 'Cognitive'},
#   {'item_number': 33,
#    'statement': 'I believe this person lacks consistency in their behavior.',
#    'dimension': 'Cognitive'},
#   {'item_number': 34,
#    'statement': 'I think this person is not genuine in their actions.',
#    'dimension': 'Cognitive'},
#   {'item_number': 35,
#    'statement': 'I suspect this person has betrayed others before.',
#    'dimension': 'Cognitive'},
#   {'item_number': 36,
#    'statement': 'I believe this person would lie to avoid responsibility.',
#    'dimension': 'Cognitive'},
#   {'item_number': 37,
#    'statement': 'I think this person would not hesitate to mislead me.',
#    'dimension': 'Cognitive'},
#   {'item_number': 38,
#    'statement': 'I assume this person’s compliments are insincere.',
#    'dimension': 'Cognitive'},
#   {'item_number': 39,
#    'statement': 'I question whether this person respects boundaries.',
#    'dimension': 'Cognitive'},
#   {'item_number': 40,
#    'statement': 'I believe this person would twist the truth to suit their needs.',
#    'dimension': 'Cognitive'},
#   {'item_number': 41,
#    'statement': 'I avoid sharing personal information with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 42,
#    'statement': 'I choose not to rely on this person for important tasks.',
#    'dimension': 'Behavioral'},
#   {'item_number': 43,
#    'statement': 'I limit my contact with this person whenever possible.',
#    'dimension': 'Behavioral'},
#   {'item_number': 44,
#    'statement': 'I take precautions when dealing with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 45,
#    'statement': 'I am careful not to reveal too much around this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 46,
#    'statement': 'I avoid putting myself in vulnerable situations with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 47,
#    'statement': 'I steer clear of situations where I must depend on this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 48,
#    'statement': 'I keep my distance from this person during group activities.',
#    'dimension': 'Behavioral'},
#   {'item_number': 49,
#    'statement': 'I avoid asking this person for help.',
#    'dimension': 'Behavioral'},
#   {'item_number': 50,
#    'statement': 'I refrain from working closely with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 51,
#    'statement': 'I am reluctant to share resources with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 52,
#    'statement': 'I hesitate to collaborate with this person on projects.',
#    'dimension': 'Behavioral'},
#   {'item_number': 53,
#    'statement': 'I avoid trusting this person with sensitive matters.',
#    'dimension': 'Behavioral'},
#   {'item_number': 54,
#    'statement': 'I prefer not to socialize with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 55,
#    'statement': 'I choose safer alternatives instead of involving this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 56,
#    'statement': 'I avoid expressing my true thoughts around this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 57,
#    'statement': 'I take extra steps to protect myself when dealing with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 58,
#    'statement': 'I double-check things this person is responsible for.',
#    'dimension': 'Behavioral'},
#   {'item_number': 59,
#    'statement': 'I avoid being alone with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 60,
#    'statement': 'I keep my opinions to myself when this person is present.',
#    'dimension': 'Behavioral'},
#   {'item_number': 61,
#    'statement': 'I stay guarded during interactions with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 62,
#    'statement': 'I avoid depending on this person in stressful situations.',
#    'dimension': 'Behavioral'},
#   {'item_number': 63,
#    'statement': 'I do not share my plans with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 64,
#    'statement': 'I act more formally around this person to protect myself.',
#    'dimension': 'Behavioral'},
#   {'item_number': 65,
#    'statement': 'I limit the amount of time I spend with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 66,
#    'statement': 'I avoid giving this person opportunities to influence me.',
#    'dimension': 'Behavioral'},
#   {'item_number': 67,
#    'statement': 'I prepare backup options when this person is involved.',
#    'dimension': 'Behavioral'},
#   {'item_number': 68,
#    'statement': 'I avoid disclosing personal goals to this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 69,
#    'statement': 'I keep important decisions away from this person’s input.',
#    'dimension': 'Behavioral'},
#   {'item_number': 70,
#    'statement': 'I try not to be influenced by this person’s opinions.',
#    'dimension': 'Behavioral'},
#   {'item_number': 71,
#    'statement': 'I refrain from including this person in group decisions.',
#    'dimension': 'Behavioral'},
#   {'item_number': 72,
#    'statement': 'I avoid casual conversation with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 73,
#    'statement': 'I monitor my behavior more closely when this person is around.',
#    'dimension': 'Behavioral'},
#   {'item_number': 74,
#    'statement': 'I avoid situations where I might owe this person a favor.',
#    'dimension': 'Behavioral'},
#   {'item_number': 75,
#    'statement': 'I make sure not to rely too heavily on this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 76,
#    'statement': 'I avoid expressing my emotions when this person is nearby.',
#    'dimension': 'Behavioral'},
#   {'item_number': 77,
#    'statement': 'I reduce interactions with this person to a minimum.',
#    'dimension': 'Behavioral'},
#   {'item_number': 78,
#    'statement': 'I feel safer when this person is not involved.',
#    'dimension': 'Behavioral'},
#   {'item_number': 79,
#    'statement': 'I avoid giving this person responsibilities that affect me.',
#    'dimension': 'Behavioral'},
#   {'item_number': 80,
#    'statement': 'I hold back in discussions when this person is present.',
#    'dimension': 'Behavioral'},
#   {'item_number': 81,
#    'statement': 'I experience unease when this person is near me.',
#    'dimension': 'Affective'},
#   {'item_number': 82,
#    'statement': 'I feel nervous when interacting with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 83,
#    'statement': 'I feel uncomfortable in this person’s presence.',
#    'dimension': 'Affective'},
#   {'item_number': 84,
#    'statement': 'I feel tense when I have to speak with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 85,
#    'statement': 'I feel irritated when this person is involved.',
#    'dimension': 'Affective'},
#   {'item_number': 86,
#    'statement': 'I feel anxious when I know I will see this person.',
#    'dimension': 'Affective'},
#   {'item_number': 87,
#    'statement': 'I feel defensive around this person.',
#    'dimension': 'Affective'},
#   {'item_number': 88,
#    'statement': 'I feel a sense of dread before meetings with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 89,
#    'statement': 'I feel emotionally drained after interacting with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 90,
#    'statement': 'I feel on edge when this person enters the room.',
#    'dimension': 'Affective'},
#   {'item_number': 91,
#    'statement': 'I feel guarded when this person talks to me.',
#    'dimension': 'Affective'},
#   {'item_number': 92,
#    'statement': 'I feel angry when I think about this person.',
#    'dimension': 'Affective'},
#   {'item_number': 93,
#    'statement': 'I feel upset after conversations with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 94,
#    'statement': 'I feel a sense of mistrust just by hearing this person’s name.',
#    'dimension': 'Affective'},
#   {'item_number': 95,
#    'statement': 'I feel suspicious whenever this person is around.',
#    'dimension': 'Affective'},
#   {'item_number': 96,
#    'statement': 'I feel a need to protect myself emotionally from this person.',
#    'dimension': 'Affective'},
#   {'item_number': 97,
#    'statement': 'I feel emotionally unsafe when this person is nearby.',
#    'dimension': 'Affective'},
#   {'item_number': 98,
#    'statement': 'I feel overwhelmed when I have to interact with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 99,
#    'statement': 'I feel uneasy about making eye contact with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 100,
#    'statement': 'I feel discomfort when this person tries to be friendly.',
#    'dimension': 'Affective'},
#   {'item_number': 101,
#    'statement': 'I feel like I need to put up a wall around this person.',
#    'dimension': 'Affective'},
#   {'item_number': 102,
#    'statement': 'I feel annoyed when this person tries to speak with me.',
#    'dimension': 'Affective'},
#   {'item_number': 103,
#    'statement': 'I feel resentment toward this person.',
#    'dimension': 'Affective'},
#   {'item_number': 104,
#    'statement': 'I feel like I can’t relax when this person is present.',
#    'dimension': 'Affective'},
#   {'item_number': 105,
#    'statement': 'I feel emotionally distant from this person.',
#    'dimension': 'Affective'},
#   {'item_number': 106,
#    'statement': 'I feel a strong dislike toward this person.',
#    'dimension': 'Affective'},
#   {'item_number': 107,
#    'statement': 'I feel that this person causes me emotional stress.',
#    'dimension': 'Affective'},
#   {'item_number': 108,
#    'statement': 'I feel my body tense up when I hear this person’s voice.',
#    'dimension': 'Affective'},
#   {'item_number': 109,
#    'statement': 'I feel distrustful emotions rise when I see this person.',
#    'dimension': 'Affective'},
#   {'item_number': 110,
#    'statement': 'I feel like avoiding eye contact with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 111,
#    'statement': 'I feel a chill in the air when this person is near.',
#    'dimension': 'Affective'},
#   {'item_number': 112,
#    'statement': 'I feel like I can’t be myself around this person.',
#    'dimension': 'Affective'},
#   {'item_number': 113,
#    'statement': 'I feel emotionally disturbed by this person’s presence.',
#    'dimension': 'Affective'},
#   {'item_number': 114,
#    'statement': 'I feel a strong need to emotionally distance myself from this person.',
#    'dimension': 'Affective'},
#   {'item_number': 115,
#    'statement': 'I feel emotionally guarded in this person’s company.',
#    'dimension': 'Affective'},
#   {'item_number': 116,
#    'statement': 'I feel unsettled after being around this person.',
#    'dimension': 'Affective'},
#   {'item_number': 117,
#    'statement': 'I feel uncomfortable even during small talk with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 118,
#    'statement': 'I feel emotionally threatened by this person’s actions.',
#    'dimension': 'Affective'},
#   {'item_number': 119,
#    'statement': 'I feel like this person brings out negative emotions in me.',
#    'dimension': 'Affective'},
#   {'item_number': 120,
#    'statement': 'I feel emotionally uneasy when this person pays attention to me.',
#    'dimension': 'Affective'}],
#  'metadata': {'total_items': 120,
#   'dimensions_list': ['Cognitive', 'Behavioral', 'Affective'],
#   'generated_from': 'auto_scale_development package',
#   'model_name': 'chatgpt-4o-latest',
#   'temperature': 0.7,
#   'top_p': 0.8},
#  'examples': {'Cognitive': ['This person would behave in a deceptive and fraudulent way.',
#    'I am suspicious of the way this person will act in the future.'],
#   'Behavioral': ['I find it necessary to be cautious with this person.',
#    'I will protect myself from being taken advantage of by this person.'],
#   'Affective': ['I feel tense when I am with this person.',
#    'I experience anxiety when interacting with this person.']}}

# %%
filtered_items = item_reduction(items, similarity_threshold=0.8, verbose=True)
filtered_items
export_items_to_json(filtered_items, "filtered_items.json")
# Out:
# /Users/pw/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# Dropping item: 'I feel like avoiding eye contact with this person....' (similarity 0.859 with item: 'I feel uneasy about making eye contact with this p...')
# Dropping item: 'I feel emotionally disturbed by this person’s pres...' (similarity 0.837 with item: 'I feel uncomfortable in this person’s presence....')
# Dropping item: 'I feel a strong need to emotionally distance mysel...' (similarity 0.895 with item: 'I feel emotionally distant from this person....')
# 'filtered_items.json'

# %%
validation_definitions = {
    "Cognitive": "Rational beliefs or expectations about another party's untrustworthiness, including suspicions about their motives, intentions, or reliability.",
    "Behavioral": "The unwillingness or avoidance of future interactions or risk-taking actions with the distrusted person, including protective behaviors.",
    "Affective": "Negative emotions directed at the distrusted person, such as anxiety, fear, anger, or discomfort."
}

validated_items = content_validation(
    items_dict=filtered_items,
    definitions=validation_definitions,
    scale_points=7,
    models=["gpt-4.1-2025-04-14", "chatgpt-4o-latest"],
    runs_per_model=2,  # Run each model multiple times for reliability
    top_n_per_dimension=5,  # Select top 5 items per dimension
    api_key=None  # Will use default API key
)

# %%
validated_items
export_items_to_json(validated_items['top_items'], "validated_items.json")
# Out:
# 'validated_items.json'

# %%
get_items(validated_items['top_items'])
# Out:
# {'items': [{'item_number': 1,
#    'statement': 'I question whether this person has honest intentions.',
#    'dimension': 'Cognitive'},
#   {'item_number': 2,
#    'statement': 'I believe this person hides their true motives.',
#    'dimension': 'Cognitive'},
#   {'item_number': 3,
#    'statement': 'I think this person would take advantage of me if given the chance.',
#    'dimension': 'Cognitive'},
#   {'item_number': 4,
#    'statement': 'I doubt this person would act in my best interest.',
#    'dimension': 'Cognitive'},
#   {'item_number': 5,
#    'statement': 'I suspect this person might mislead me.',
#    'dimension': 'Cognitive'},
#   {'item_number': 41,
#    'statement': 'I avoid sharing personal information with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 42,
#    'statement': 'I choose not to rely on this person for important tasks.',
#    'dimension': 'Behavioral'},
#   {'item_number': 43,
#    'statement': 'I limit my contact with this person whenever possible.',
#    'dimension': 'Behavioral'},
#   {'item_number': 44,
#    'statement': 'I take precautions when dealing with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 45,
#    'statement': 'I am careful not to reveal too much around this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 81,
#    'statement': 'I experience unease when this person is near me.',
#    'dimension': 'Affective'},
#   {'item_number': 82,
#    'statement': 'I feel nervous when interacting with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 83,
#    'statement': 'I feel uncomfortable in this person’s presence.',
#    'dimension': 'Affective'},
#   {'item_number': 84,
#    'statement': 'I feel tense when I have to speak with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 85,
#    'statement': 'I feel irritated when this person is involved.',
#    'dimension': 'Affective'}]}

# %%
from auto_scale_development import item_generation, export_items_to_excel, export_items_to_json, item_reduction, content_validation, get_items

get_items(items)
# Out:
# {'items': [{'item_number': 1,
#    'statement': 'I question this person’s true intentions.',
#    'dimension': 'Cognitive'},
#   {'item_number': 2,
#    'statement': 'I believe this person would take advantage of me if given the chance.',
#    'dimension': 'Cognitive'},
#   {'item_number': 3,
#    'statement': 'I doubt that this person would keep a promise.',
#    'dimension': 'Cognitive'},
#   {'item_number': 4,
#    'statement': 'I think this person hides important information from me.',
#    'dimension': 'Cognitive'},
#   {'item_number': 5,
#    'statement': 'I believe this person would act selfishly in a difficult situation.',
#    'dimension': 'Cognitive'},
#   {'item_number': 6,
#    'statement': 'I suspect this person might betray my confidence.',
#    'dimension': 'Cognitive'},
#   {'item_number': 7,
#    'statement': 'I think this person would lie to protect themselves.',
#    'dimension': 'Cognitive'},
#   {'item_number': 8,
#    'statement': 'I believe this person is more concerned with their own benefit than fairness.',
#    'dimension': 'Cognitive'},
#   {'item_number': 9,
#    'statement': 'I expect this person to manipulate others for personal gain.',
#    'dimension': 'Cognitive'},
#   {'item_number': 10,
#    'statement': 'I think this person would act dishonestly under pressure.',
#    'dimension': 'Cognitive'},
#   {'item_number': 11,
#    'statement': 'I am convinced this person does not have good intentions.',
#    'dimension': 'Cognitive'},
#   {'item_number': 12,
#    'statement': 'I believe this person is not reliable in serious matters.',
#    'dimension': 'Cognitive'},
#   {'item_number': 13,
#    'statement': 'I assume this person is capable of deceit.',
#    'dimension': 'Cognitive'},
#   {'item_number': 14,
#    'statement': 'I believe this person would let me down when it matters.',
#    'dimension': 'Cognitive'},
#   {'item_number': 15,
#    'statement': 'I think this person would withhold the truth if it benefited them.',
#    'dimension': 'Cognitive'},
#   {'item_number': 16,
#    'statement': 'I expect this person to prioritize themselves over others.',
#    'dimension': 'Cognitive'},
#   {'item_number': 17,
#    'statement': 'I believe this person would break a rule to get ahead.',
#    'dimension': 'Cognitive'},
#   {'item_number': 18,
#    'statement': 'I think this person would act in a way that harms others if it served their interest.',
#    'dimension': 'Cognitive'},
#   {'item_number': 19,
#    'statement': 'I expect this person to behave unethically if they could get away with it.',
#    'dimension': 'Cognitive'},
#   {'item_number': 20,
#    'statement': 'I believe this person lacks moral integrity.',
#    'dimension': 'Cognitive'},
#   {'item_number': 21,
#    'statement': 'I think this person would mislead others to protect their image.',
#    'dimension': 'Cognitive'},
#   {'item_number': 22,
#    'statement': 'I assume this person is not honest in their communication.',
#    'dimension': 'Cognitive'},
#   {'item_number': 23,
#    'statement': 'I believe this person would exploit someone if they had the chance.',
#    'dimension': 'Cognitive'},
#   {'item_number': 24,
#    'statement': 'I think this person conceals their true motives.',
#    'dimension': 'Cognitive'},
#   {'item_number': 25,
#    'statement': 'I believe this person is not sincere in their actions.',
#    'dimension': 'Cognitive'},
#   {'item_number': 26,
#    'statement': 'I assume this person would only help if it benefited them.',
#    'dimension': 'Cognitive'},
#   {'item_number': 27,
#    'statement': 'I think this person would shift blame to others.',
#    'dimension': 'Cognitive'},
#   {'item_number': 28,
#    'statement': 'I believe this person is not dependable in challenging times.',
#    'dimension': 'Cognitive'},
#   {'item_number': 29,
#    'statement': 'I expect this person to act in their own interest regardless of others.',
#    'dimension': 'Cognitive'},
#   {'item_number': 30,
#    'statement': 'I believe this person would twist facts to suit their goals.',
#    'dimension': 'Cognitive'},
#   {'item_number': 31,
#    'statement': 'I think this person would take credit for others’ work.',
#    'dimension': 'Cognitive'},
#   {'item_number': 32,
#    'statement': 'I believe this person lacks consistency in their values.',
#    'dimension': 'Cognitive'},
#   {'item_number': 33,
#    'statement': 'I assume this person would ignore the rules when convenient.',
#    'dimension': 'Cognitive'},
#   {'item_number': 34,
#    'statement': 'I think this person would misrepresent the truth.',
#    'dimension': 'Cognitive'},
#   {'item_number': 35,
#    'statement': 'I believe this person has hidden agendas.',
#    'dimension': 'Cognitive'},
#   {'item_number': 36,
#    'statement': 'I expect this person to manipulate situations to their advantage.',
#    'dimension': 'Cognitive'},
#   {'item_number': 37,
#    'statement': 'I think this person acts out of self-interest.',
#    'dimension': 'Cognitive'},
#   {'item_number': 38,
#    'statement': 'I believe this person would abandon others in a crisis.',
#    'dimension': 'Cognitive'},
#   {'item_number': 39,
#    'statement': 'I assume this person is not trustworthy in sensitive matters.',
#    'dimension': 'Cognitive'},
#   {'item_number': 40,
#    'statement': 'I think this person would deceive others to maintain control.',
#    'dimension': 'Cognitive'},
#   {'item_number': 41,
#    'statement': 'I avoid making plans that depend on this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 42,
#    'statement': 'I keep my distance from this person when possible.',
#    'dimension': 'Behavioral'},
#   {'item_number': 43,
#    'statement': 'I choose not to rely on this person for important tasks.',
#    'dimension': 'Behavioral'},
#   {'item_number': 44,
#    'statement': 'I hold back from sharing personal information with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 45,
#    'statement': 'I make sure to protect myself when dealing with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 46,
#    'statement': 'I avoid situations where I would have to trust this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 47,
#    'statement': 'I limit my interactions with this person to avoid problems.',
#    'dimension': 'Behavioral'},
#   {'item_number': 48,
#    'statement': 'I prefer to keep this person at arm’s length.',
#    'dimension': 'Behavioral'},
#   {'item_number': 49,
#    'statement': 'I avoid taking risks that involve this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 50,
#    'statement': 'I choose to verify what this person says before acting on it.',
#    'dimension': 'Behavioral'},
#   {'item_number': 51,
#    'statement': 'I avoid giving this person any responsibility over my affairs.',
#    'dimension': 'Behavioral'},
#   {'item_number': 52,
#    'statement': 'I hold back from forming a close relationship with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 53,
#    'statement': 'I avoid being vulnerable around this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 54,
#    'statement': 'I take extra precautions when dealing with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 55,
#    'statement': 'I am cautious when agreeing to things with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 56,
#    'statement': 'I avoid depending on this person for support.',
#    'dimension': 'Behavioral'},
#   {'item_number': 57,
#    'statement': 'I do not include this person in important decisions.',
#    'dimension': 'Behavioral'},
#   {'item_number': 58,
#    'statement': 'I check facts before accepting what this person says.',
#    'dimension': 'Behavioral'},
#   {'item_number': 59,
#    'statement': 'I stay guarded in conversations with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 60,
#    'statement': 'I try not to be alone with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 61,
#    'statement': 'I avoid discussing sensitive matters with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 62,
#    'statement': 'I don’t ask this person for help even when I need it.',
#    'dimension': 'Behavioral'},
#   {'item_number': 63,
#    'statement': 'I keep records of interactions with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 64,
#    'statement': 'I double-check anything this person is responsible for.',
#    'dimension': 'Behavioral'},
#   {'item_number': 65,
#    'statement': 'I avoid giving this person any control over shared tasks.',
#    'dimension': 'Behavioral'},
#   {'item_number': 66,
#    'statement': 'I don’t share plans with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 67,
#    'statement': 'I am hesitant to cooperate with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 68,
#    'statement': 'I stay alert when this person is involved in a situation.',
#    'dimension': 'Behavioral'},
#   {'item_number': 69,
#    'statement': 'I try to keep interactions with this person brief.',
#    'dimension': 'Behavioral'},
#   {'item_number': 70,
#    'statement': 'I avoid working closely with this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 71,
#    'statement': 'I don’t feel safe relying on this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 72,
#    'statement': 'I withhold my opinions when this person is present.',
#    'dimension': 'Behavioral'},
#   {'item_number': 73,
#    'statement': 'I keep backup plans in case this person fails to follow through.',
#    'dimension': 'Behavioral'},
#   {'item_number': 74,
#    'statement': 'I stay emotionally detached from this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 75,
#    'statement': 'I avoid being open around this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 76,
#    'statement': 'I keep important details to myself when this person is involved.',
#    'dimension': 'Behavioral'},
#   {'item_number': 77,
#    'statement': 'I take steps to ensure this person cannot interfere with my goals.',
#    'dimension': 'Behavioral'},
#   {'item_number': 78,
#    'statement': 'I avoid giving this person the chance to disappoint me.',
#    'dimension': 'Behavioral'},
#   {'item_number': 79,
#    'statement': 'I avoid making plans that involve this person.',
#    'dimension': 'Behavioral'},
#   {'item_number': 80,
#    'statement': 'I take steps to limit what this person can do to affect me.',
#    'dimension': 'Behavioral'},
#   {'item_number': 81,
#    'statement': 'I feel uneasy when this person is around.',
#    'dimension': 'Affective'},
#   {'item_number': 82,
#    'statement': 'I experience tension when I talk to this person.',
#    'dimension': 'Affective'},
#   {'item_number': 83,
#    'statement': 'I feel nervous in this person’s presence.',
#    'dimension': 'Affective'},
#   {'item_number': 84,
#    'statement': 'I feel a sense of dread when I know I’ll see this person.',
#    'dimension': 'Affective'},
#   {'item_number': 85,
#    'statement': 'I get irritated when I have to interact with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 86,
#    'statement': 'I feel emotionally uncomfortable around this person.',
#    'dimension': 'Affective'},
#   {'item_number': 87,
#    'statement': 'I feel defensive when this person speaks to me.',
#    'dimension': 'Affective'},
#   {'item_number': 88,
#    'statement': 'I feel angry just thinking about this person.',
#    'dimension': 'Affective'},
#   {'item_number': 89,
#    'statement': 'I feel unsettled when this person enters the room.',
#    'dimension': 'Affective'},
#   {'item_number': 90,
#    'statement': 'I feel anxious when I have to depend on this person.',
#    'dimension': 'Affective'},
#   {'item_number': 91,
#    'statement': 'I feel stressed when this person is involved in a task.',
#    'dimension': 'Affective'},
#   {'item_number': 92,
#    'statement': 'I feel upset when I remember things this person has done.',
#    'dimension': 'Affective'},
#   {'item_number': 93,
#    'statement': 'I feel fear when I think this person has influence over a situation.',
#    'dimension': 'Affective'},
#   {'item_number': 94,
#    'statement': 'I feel guarded in this person’s presence.',
#    'dimension': 'Affective'},
#   {'item_number': 95,
#    'statement': 'I feel emotionally drained after interacting with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 96,
#    'statement': 'I feel on edge when I’m near this person.',
#    'dimension': 'Affective'},
#   {'item_number': 97,
#    'statement': 'I feel frustrated when I have to cooperate with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 98,
#    'statement': 'I feel resentment toward this person.',
#    'dimension': 'Affective'},
#   {'item_number': 99,
#    'statement': 'I feel powerless when this person is in control.',
#    'dimension': 'Affective'},
#   {'item_number': 100,
#    'statement': 'I feel suspicious every time this person speaks.',
#    'dimension': 'Affective'},
#   {'item_number': 101,
#    'statement': 'I feel disrespected by this person.',
#    'dimension': 'Affective'},
#   {'item_number': 102,
#    'statement': 'I feel insecure when this person is around.',
#    'dimension': 'Affective'},
#   {'item_number': 103,
#    'statement': 'I feel emotionally unsafe around this person.',
#    'dimension': 'Affective'},
#   {'item_number': 104,
#    'statement': 'I feel like I need to protect myself emotionally from this person.',
#    'dimension': 'Affective'},
#   {'item_number': 105,
#    'statement': 'I feel cold toward this person.',
#    'dimension': 'Affective'},
#   {'item_number': 106,
#    'statement': 'I feel a sense of hostility toward this person.',
#    'dimension': 'Affective'},
#   {'item_number': 107,
#    'statement': 'I feel emotionally distant from this person.',
#    'dimension': 'Affective'},
#   {'item_number': 108,
#    'statement': 'I feel irritated by this person’s presence.',
#    'dimension': 'Affective'},
#   {'item_number': 109,
#    'statement': 'I feel uneasy sharing space with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 110,
#    'statement': 'I feel suspicious when this person acts friendly.',
#    'dimension': 'Affective'},
#   {'item_number': 111,
#    'statement': 'I feel emotionally threatened by this person.',
#    'dimension': 'Affective'},
#   {'item_number': 112,
#    'statement': 'I feel like I cannot relax when this person is nearby.',
#    'dimension': 'Affective'},
#   {'item_number': 113,
#    'statement': 'I feel that this person brings negative energy into interactions.',
#    'dimension': 'Affective'},
#   {'item_number': 114,
#    'statement': 'I feel uncomfortable making eye contact with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 115,
#    'statement': 'I feel emotionally tense when this person is involved.',
#    'dimension': 'Affective'},
#   {'item_number': 116,
#    'statement': 'I feel that I need to suppress my emotions around this person.',
#    'dimension': 'Affective'},
#   {'item_number': 117,
#    'statement': 'I feel that my mood worsens when I interact with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 118,
#    'statement': 'I feel uneasy about sharing my thoughts with this person.',
#    'dimension': 'Affective'},
#   {'item_number': 119,
#    'statement': 'I feel that this person triggers negative emotions in me.',
#    'dimension': 'Affective'},
#   {'item_number': 120,
#    'statement': 'I feel emotionally exposed when I’m around this person.',
#    'dimension': 'Affective'}]}

# %%
export_items_to_json(items, "items.json")
# Out:
# 'items.json'
